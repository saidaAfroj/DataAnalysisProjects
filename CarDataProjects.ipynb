# %%
#To see how many rows and columns this dataset contains
car.shape
# Out:
# (432, 15)

# %%
#Next step is to clean the data , if theres any null value then fill it with the mean value of that column
#To see how many null values are there in all the columns we need to call isnull() function
car.isnull()
# Out:
#       Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0    False  False  False   False       False  False    False       False
# 1    False  False  False   False       False  False    False       False
# 2    False  False  False   False       False  False    False       False
# 3    False  False  False   False       False  False    False       False
# 4    False  False  False   False       False  False    False       False
# ..     ...    ...    ...     ...         ...    ...      ...         ...
# 427  False  False  False   False       False  False    False       False
# 428  False  False  False   False       False  False    False       False
# 429  False  False  False   False       False  False    False       False
# 430  False  False  False   False       False  False    False       False
# 431  False  False  False   False       False  False    False       False
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
#if want to see overall the sum of null values need to call sum function over the dataframe_name.isnull() funtion
car.isnull().sum()
#here we can see the total number of null values each column has . sum of total null values in each column
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
#Next step is : if there is any null values then need to fill the null value with the mean of that columns
car['Cylinders'].fillna(car['Cylinders'].mean(), inplace=True)
# Out:
# C:\Users\saida\AppData\Local\Temp\ipykernel_13120\251731769.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['Cylinders'].fillna(car['Cylinders'].mean(), inplace=True)

# %%
car.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
car['EngineSize'].fillna(car['EngineSize'].mean(), inplace=True)
car['MPG_City'].fillna(car['MPG_City'].mean(), inplace=True)
car['Weight'].fillna(car['Weight'].mean(), inplace=True)
car['Wheelbase'].fillna(car['Wheelbase'].mean() , inplace=True)
car['Length'].fillna(car['Length'].mean(), inplace=True)
car['MPG_Highway'].fillna(car['MPG_Highway'].mean(), inplace=True)
car['Cylinders'].fillna(car['Cylinders'].mean(), inplace=True)
# Out:
# C:\Users\saida\AppData\Local\Temp\ipykernel_13120\3092223680.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['EngineSize'].fillna(car['EngineSize'].mean(), inplace=True)
# C:\Users\saida\AppData\Local\Temp\ipykernel_13120\3092223680.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
car.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      6
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
car['Horsepower'].fillna(car['Horsepower'].mean(), inplace=True)
# Out:
# C:\Users\saida\AppData\Local\Temp\ipykernel_13120\3664208440.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['Horsepower'].fillna(car['Horsepower'].mean(), inplace=True)

# %%
#fill up the null values of those column which has string/object values ( not int values) by the following ways
#inplace = true is used to make a change permanantly 
car["Make"].fillna("No input", inplace = True)
car["Model"].fillna("No input", inplace = True)
car["Type"].fillna("No input", inplace = True)
car["Origin"].fillna("No input", inplace = True)
car["DriveTrain"].fillna("No input", inplace = True)
car["MSRP"].fillna("No input", inplace = True)
car["Invoice"].fillna("No input", inplace = True)
# Out:
# C:\Users\saida\AppData\Local\Temp\ipykernel_13120\4050869427.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car["Invoice"].fillna("No input", inplace = True)

# %%
#Check what are the different types of Make are there in dataset, And what is the count of each Make in the dataset
#Need to write a function which will count how many kind are there in each "Make"
#its displaying each type of make and total num of each make ( such as Toyota 28 times )
car['Make'].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Mitsubishi       13
# Dodge            13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Kia              11
# Mazda            11
# Lexus            11
# Pontiac          11
# Subaru           11
# Lincoln           9
# Mercury           9
# Buick             9
# Saturn            8
# Infiniti          8
# GMC               8
# Cadillac          8
# Suzuki            8
# Porsche           7
# Saab              7
# Acura             7
# No input          4
# Oldsmobile        3
# Jeep              3
# Land Rover        3
# MINI              2
# Scion             2
# Isuzu             2
# Hummer            1
# Name: count, dtype: int64

# %%
#Show all the records where origin is asia or europe
#1st just finding which 
car['Origin'].isin(['Asia','Europe'])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 427    True
# 428    True
# 429    True
# 430    True
# 431    True
# Name: Origin, Length: 432, dtype: bool

# %%
#Need to show all colums info of those where origin is Asia or Europe 
#Need to put the function inside the dataframe to display all column info where origin = europe/Asia
car[car['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
#Remove all the rows where weight is above 4000
#1st need to find out the rows which has weight above 4000
car['Weight'] > 4000
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# Name: Weight, Length: 432, dtype: bool

# %%
#if want to display all records of all columns where weight >4000 then need to put this condition inside the dataframe 
car[car['Weight'] >4000 ]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
#Remove all the rows where weight is above 4000
#1st need to find out the rows which has weight above 4000
#car['Weight'] > 4000
#if want to display all records of all columns where weight >4000 then need to put this condition inside the dataframe 
#car[car['Weight'] >4000 ]
#Now need to remove these rows where weight>4000; for that just need to use '~ ' before the condition ; and put the condn inside '()'
car[~(car['Weight'] >4000)]
#you can check if the resulted data set is right or wrong by checking the # of rows before and after and substract the # of rows which is above 4000
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
#total row was 432 , weight>4000 has 103 rows . so 
432 - 103
#after removing those rows which has above 4000 weight , total rows will reduce to 329
# Out:
# 329

# %%
#Increase all the values of "MPG city" column by 3
car["MPG_City"].apply(lambda x:x+3)
# Out:
# 0      20.0
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 432, dtype: float64

# %%
#Need to display all the columns after applying the condition 
car["MPG_City"]= car["MPG_City"].apply(lambda x:x+3)
#all values of MPG city has increased by 3

# %%
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
